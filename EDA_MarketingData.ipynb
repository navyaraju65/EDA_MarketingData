# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the dataset
marketing_data = pd.read_csv("C:\\Users\\navya\\Downloads\\Marketing - recordid_name_gender_age_location_email_phone_product_category_amount.csv")

# Display the first few rows of the dataframe
marketing_data.head(10)
# Out:
#    RecordID              Name  Gender  Age       Location  \
# 0      1001        John Smith    Male   32       New York
# 1      1002     Sarah Johnson  Female   28    Los Angeles
# 2      1003     Michael Brown    Male   45        Chicago
# 3      1004       Emily Davis  Female   35  San Francisco
# 4      1005      David Wilson    Male   39          Miami
# 5      1006  Jessica Anderson  Female   24         Dallas
# 6      1007  Matthew Martinez    Male   41        Houston
# 7      1008     Amanda Taylor  Female   33        Seattle
# 8      1009  Andrew Hernandez    Male   29         Boston
# 9      1010     Sophia Martin  Female   27         Austin
#
#                          Email          Phone     Product     Category  Amount
# 0        johnsmith@example.com  555-1234-5678       Shoes     Footwear   89.99
# 1     sarahjohnson@example.com  555-9876-5432     T-Shirt      Apparel   19.99
# 2     michaelbrown@example.com  555-2345-6789       Watch  Accessories  199.99
# 3       emilydavis@example.com  555-8765-4321  Sunglasses  Accessories   59.99
# 4      davidwilson@example.com  555-3456-7890  Headphones  Electronics  149.99
# 5  jessicaanderson@example.com  555-7654-3210    Backpack         Bags   49.99
# 6  matthewmartinez@example.com  555-4567-8901     Perfume       Beauty   79.99
# 7     amandataylor@example.com  555-6543-2109         Hat  Accessories   29.99
# 8  andrewhernandez@example.com  555-5678-9012      Jacket      Apparel  119.99
# 9     sophiamartin@example.com  555-7890-1234  Smartphone  Electronics  699.99

# %%
# Check the data types and look for any issues with the data
data_types = marketing_data.dtypes

data_types
# Out:
# RecordID      int64
# Name         object
# Gender       object
# Age           int64
# Location     object
# Email        object
# Phone        object
# Product      object
# Category     object
# Amount      float64
# dtype: object

# %%
# Check for any missing values
missing_values = marketing_data.isnull().sum()

missing_values
# Out:
# RecordID    0
# Name        0
# Gender      0
# Age         0
# Location    0
# Email       0
# Phone       0
# Product     0
# Category    0
# Amount      0
# dtype: int64

# %%
# Summarize the dataset for numerical fields
summary_statistics = marketing_data.describe()

summary_statistics
# Out:
#           RecordID         Age      Amount
# count   100.000000  100.000000  100.000000
# mean   1050.500000   31.240000  129.590000
# std      29.011492    4.581738  146.480047
# min    1001.000000   24.000000   19.990000
# 25%    1025.750000   28.000000   59.990000
# 50%    1050.500000   30.000000   79.990000
# 75%    1075.250000   34.000000  149.990000
# max    1100.000000   45.000000  699.990000

# %%
# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Plot distribution of the Age column
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.histplot(marketing_data['Age'], bins=10, kde=True)
plt.title('Age Distribution')

# Plot distribution of the Amount column
plt.subplot(1, 2, 2)
sns.histplot(marketing_data['Amount'], bins=10, kde=True)
plt.title('Amount Spent Distribution')

plt.show()

# %%
# Plotting count plots for categorical variables

plt.figure(figsize=(18, 12))

# Plot distribution of the Product column
plt.subplot(2, 2, 3)
sns.countplot(x='Product', data=marketing_data)
plt.title('Product Distribution')
plt.xticks(rotation=90)
# Plot distribution of the Category column
plt.subplot(2, 2, 4)
sns.countplot(x='Category', data=marketing_data)
plt.title('Category Distribution')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()
